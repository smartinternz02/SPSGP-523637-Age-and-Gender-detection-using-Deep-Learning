# %%
#NAMANI HARSHITH - 20MID0157
#TASK - 1

import numpy as np
import pandas as pd

# Create random values
data = np.random.rand(4,4)

# Create the DataFrame
df= pd.DataFrame(data, columns=['Feature1','Feature2','Feature3','Feature4'])

print(df)
# Out:
#    Feature1  Feature2  Feature3  Feature4
# 0  0.422446  0.414134  0.823041  0.201926
# 1  0.934188  0.970769  0.837816  0.084208
# 2  0.550103  0.905246  0.041246  0.947384
# 3  0.437781  0.730391  0.543021  0.898875

# %%
#TASK - 2
# Rename the column names
new_column_names = {
    'Feature1': 'Random value 1',
    'Feature2': 'Random value 2',
    'Feature3': 'Random value 3',
    'Feature4': 'Random value 4'
}

df = df.rename(columns=new_column_names)

print(df)
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.422446        0.414134        0.823041        0.201926
# 1        0.934188        0.970769        0.837816        0.084208
# 2        0.550103        0.905246        0.041246        0.947384
# 3        0.437781        0.730391        0.543021        0.898875

# %%
#TASK - 3

# Display descriptive statistics
df_stats = df.describe()

# Print the statistics
print(df_stats)
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.586129        0.755135        0.561281        0.533098
# std          0.238916        0.248948        0.372272        0.453359
# min          0.422446        0.414134        0.041246        0.084208
# 25%          0.433947        0.651327        0.417577        0.172496
# 50%          0.493942        0.817819        0.683031        0.550401
# 75%          0.646124        0.921627        0.826735        0.911002
# max          0.934188        0.970769        0.837816        0.947384

# %%
#TASK - 4

# Check for null values
null_values = df.isnull().sum()

# Find data types of columns
data_types = df.dtypes

# Print null values
print("Null Values:")
print(null_values)

# Print data types
print("\nData Types:")
print(data_types)
# Out:
# Null Values:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64
#
# Data Types:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
#TASK - 5

df[['Random value 2', 'Random value 3']]

# Display columns using index location method
df.iloc[:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.414134        0.823041
# 1        0.970769        0.837816
# 2        0.905246        0.041246
# 3        0.730391        0.543021
